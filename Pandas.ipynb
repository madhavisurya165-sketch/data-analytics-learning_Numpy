# %%
## read_csv create Dataframe as default and not series

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series from list

# %%
Country = ['India','Japan','USA','UK']
pd.Series(Country)                        #most of the time if data type is object then it is string
# Out:
# 0    India
# 1    Japan
# 2      USA
# 3       UK
# dtype: object

# %%
numbers = [12,13,14,15,16]
pd.Series(numbers)
# Out:
# 0    12
# 1    13
# 2    14
# 3    15
# 4    16
# dtype: int64

# %% [markdown]
# ## custom index

# %%
marks = [65,67,98,55]
subject = ['English','DBMS','Networking','BEE']

pd.Series(marks , index = subject)
# Out:
# English       65
# DBMS          67
# Networking    98
# BEE           55
# dtype: int64

# %% [markdown]
# ## setting a name

# %%
pd.Series(marks , index = subject , name ='First years marks')
# Out:
# English       65
# DBMS          67
# Networking    98
# BEE           55
# Name: First years marks, dtype: int64

# %%
marks = pd.Series({
    'maths':67,
    'English':98,
    'DBMS':77,
    'BEE':89
}, name='Second year marks')

# %% [markdown]
# ## Series Attributes

# %%
#dtype
print(marks.dtype)
print(marks.name)
print(marks.size)
print(marks.index)
print(marks.values)
# Out:
# int64
# Second year marks
# 4
# Index(['maths', 'English', 'DBMS', 'BEE'], dtype='object')
# [67 98 77 89]

# %%
#is_unique - it tells if items in your series are unique or not 
marks.is_unique
#giving true because there is not duplicate value in series
# Out:
# True

# %%
movies = pd.read_csv(r"C:\Users\Madhavi\Downloads\bollywood.csv",index_col='movie')
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
pd.read_csv(r"C:\Users\Madhavi\Downloads\kohli_ipl.csv")
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
vk = pd.read_csv(r"C:\Users\Madhavi\Downloads\kohli_ipl.csv",index_col ='match_no')
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
subs = pd.read_csv(r"C:\Users\Madhavi\Downloads\subs.csv")
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %% [markdown]
# ## series methods

# %%
subs.head(10)
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44
# 5                  46
# 6                  33
# 7                  40
# 8                  44
# 9                  74

# %%
subs.tail(5)
# Out:
#      Subscribers gained
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172

# %%
movies.sample
movies.shape
movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Kashmira Shah        1
# Kartik Elangovan     1
# Karisma Kapoor       1
# Karan Sharma         1
# Zulfi Sayed          1
# Name: count, Length: 566, dtype: int64

# %%
#sort values 
vk.sort_values(by='runs',ascending=False).head()
# Out:
#           runs
# match_no
# 128        113
# 126        109
# 123        108
# 164        100
# 120        100

# %%
#sort values -> inplace (inplace make changes in original series)
vk.sort_values(by='runs',ascending=False,inplace=True)
vk
# Out:
#           runs
# match_no
# 128        113
# 126        109
# 123        108
# 120        100
# 164        100
# ...        ...
# 211          0
# 8            0
# 130          0
# 135          0
# 87           0
#
# [215 rows x 1 columns]

# %%
movies.count()
# Out:
# lead    1500
# dtype: int64

# %%
vk.sum()
print(vk.product())
print(vk.min())
print(vk.max())
print(vk.median())
print(vk.std())
print(vk.var())
# Out:
# runs    0
# dtype: int64
# runs    0
# dtype: int64
# runs    113
# dtype: int64
# runs    24.0
# dtype: float64
# runs    26.229801
# dtype: float64
# runs    688.002478
# dtype: float64

# %%
vk.describe()
# Out:
#              runs
# count  215.000000
# mean    30.855814
# std     26.229801
# min      0.000000
# 25%      9.000000
# 50%     24.000000
# 75%     48.000000
# max    113.000000

# %%
subs.describe()
# Out:
#        Subscribers gained
# count          365.000000
# mean           135.643836
# std             62.675023
# min             33.000000
# 25%             88.000000
# 50%            123.000000
# 75%            177.000000
# max            396.000000

# %% [markdown]
# ## series indexing
# -ve index does not work here

# %%
x = pd.Series([12,23,11,24,34,35,65,67,88,11])
x[0]
# Out:
# 12

# %%
vk[5:90]
# Out:
#           runs
# match_no
# 82          99
# 81          93
# 145         92
# 178         90
# 160         84
# ...        ...
# 185         33
# 181         33
# 149         32
# 78          32
# 109         32
#
# [85 rows x 1 columns]

# %%
vk[:-1]
# Out:
#           runs
# match_no
# 128        113
# 126        109
# 123        108
# 120        100
# 164        100
# ...        ...
# 91           0
# 211          0
# 8            0
# 130          0
# 135          0
#
# [214 rows x 1 columns]

# %% [markdown]
# ## fancy indexing

# %%
#it only works with series and not with dataFrames 
x[[1,2,3,4]]
# Out:
# 1    23
# 2    11
# 3    24
# 4    34
# dtype: int64

# %%
marks
# Out:
# maths      67
# English    98
# DBMS       77
# BEE        89
# Name: Second year marks, dtype: int64

# %%
marks[1]=100
marks
# Out:
# C:\Users\Madhavi\AppData\Local\Temp\ipykernel_21712\1043635770.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks[1]=100
# maths       67
# English    100
# DBMS        77
# BEE         89
# Name: Second year marks, dtype: int64

# %% [markdown]
# ## series with python functionality

# %%
print(len(subs))
#print(dir(movies)) #it gives attributes and methods in the seies
print(sorted(subs))
# Out:
# 365
# ['Subscribers gained']

# %%
#type conversion 
list(marks)
dict(marks)
# Out:
# {'maths': 67, 'English': 24, 'DBMS': 45, 'BEE': 89}

# %%
#membership operator (in operator)
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
'Shah Rukh Khan' in movies
# Out:
# False

# %%
for i in movies.index:
    print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(15).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %% [markdown]
# ## DATAFRAME

# %%
students= [
   ['jaya','alex',],
    ['jeel','mike']
]
pd.DataFrame(students,columns=['Girls','Boys'])
# Out:
#   Girls  Boys
# 0  jaya  alex
# 1  jeel  mike
